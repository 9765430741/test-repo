# %%
from flask import Flask

app=Flask(__name__)
# app object created for flask app
print(__name__)
@app.route("/")
#decorator # use for App routing means mapping the URLS to a specfic function
#that will handle the logic for that URL.
def hello_world():
    print("********", __name__)
    return "hello world"

@app.route("/new")
#decorator # use for App routing means mapping the URLS to a specfic function
#that will handle the logic for that URL.
def hello_world1():
    return "hello world, hows everthing "

  


app.run(host="127.0.0.5")
# Out:
# __main__
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.5:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [20/Jul/2022 20:26:46] "GET / HTTP/1.1" 200 -
# ******** __main__
# 127.0.0.1 - - [20/Jul/2022 20:26:48] "GET /favicon.ico HTTP/1.1" 404 -

# %%
pip install flask

# %%
import flask

# %% [markdown]
# how to setup python interpreter in pycharm or vscode

# %% [markdown]
# ![flask1.PNG](attachment:flask1.PNG)

# %% [markdown]
# ![flask2.PNG](attachment:flask2.PNG)

# %% [markdown]
# ![flask3.PNG](attachment:flask3.PNG)

# %% [markdown]
# ![flask4.PNG](attachment:flask4.PNG)

# %% [markdown]
# ![flask5.PNG](attachment:flask5.PNG)

# %% [markdown]
# Object serialization is the process of converting state of an object into byte stream. This byte stream can further be stored in any file-like object such as a disk file or memory stream. It can also be transmitted via sockets etc. Deserialization is the process of reconstructing the object from the byte stream.
